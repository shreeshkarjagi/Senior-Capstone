# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

# Dummy predicted and true labels
y_pred = ['left', 'right', 'up', 'down', 'left', 'up', 'up', 'down', 'left', 'left', 'up', 'right', 'down', 'down', 'left', 'right']
y_true = ['left', 'right', 'up', 'down', 'right', 'up', 'down', 'down', 'right', 'left', 'up', 'right', 'down', 'down', 'left', 'right']

# Create confusion matrix
cm = confusion_matrix(y_true, y_pred, labels=['left', 'right', 'up', 'down'])
cm_norm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis] # Normalize

# Plot confusion matrix
fig, ax = plt.subplots()
im = ax.imshow(cm_norm, interpolation='nearest', cmap=plt.cm.Blues)
ax.set(xticks=np.arange(cm_norm.shape[1]), yticks=np.arange(cm_norm.shape[0]),
       xticklabels=['left', 'right', 'up', 'down'], yticklabels=['left', 'right', 'up', 'down'],
       title='Normalized Confusion Matrix', ylabel='True label', xlabel='Predicted label')
plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")

# Add values to the plot
thresh = cm_norm.max() / 2.
for i in range(cm_norm.shape[0]):
    for j in range(cm_norm.shape[1]):
        ax.text(j, i, format(cm_norm[i, j], '.2f'), ha="center", va="center",
                color="white" if cm_norm[i, j] > thresh else "black")

# Display average performance metrics
acc = accuracy_score(y_true, y_pred)
prec = precision_score(y_true, y_pred, average='macro')
rec = recall_score(y_true, y_pred, average='macro')
f1 = f1_score(y_true, y_pred, average='macro')
print(f'Accuracy: {acc:.2f}, Precision: {prec:.2f}, Recall: {rec:.2f}, F1-score: {f1:.2f}')
# Add colorbar
cbar = ax.figure.colorbar(im, ax=ax)
cbar.ax.set_ylabel('Normalized Counts', rotation=-90, va="bottom")
fig, ax = plt.subplots(figsize=(6, 4))


plt.show()
# Out:
# Accuracy: 0.81, Precision: 0.84, Recall: 0.85, F1-score: 0.81

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

# Dummy predicted and true labels
y_pred = ['left', 'right', 'up', 'down', 'left', 'up', 'up', 'down', 'left', 'left', 'up', 'right', 'down', 'down', 'left', 'right']
y_true = ['left', 'right', 'up', 'down', 'right', 'up', 'down', 'down', 'right', 'left', 'up', 'right', 'down', 'down', 'left', 'right']

# Create confusion matrix
cm = confusion_matrix(y_true, y_pred, labels=['left', 'right', 'up', 'down'])
cm_norm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis] # Normalize

# Plot confusion matrix
fig, ax = plt.subplots()
im = ax.imshow(cm_norm, interpolation='nearest', cmap=plt.cm.Blues, alpha=0.5)
ax.set(xticks=np.arange(cm_norm.shape[1]), yticks=np.arange(cm_norm.shape[0]),
       xticklabels=['left', 'right', 'up', 'down'], yticklabels=['left', 'right', 'up', 'down'],
       title='Normalized Confusion Matrix', ylabel='True label', xlabel='Predicted label')
plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")

# Add values to the plot
thresh = cm_norm.max() / 2.
for i in range(cm_norm.shape[0]):
    for j in range(cm_norm.shape[1]):
        ax.text(j, i, format(cm_norm[i, j], '.2f'), ha="center", va="center",
                color="white" if cm_norm[i, j] > thresh else "black")

# Display average performance metrics
# acc = accuracy_score(y_true, y_pred)
# prec = precision_score(y_true, y_pred, average='macro')
# rec = recall_score(y_true, y_pred, average='macro')
# f1 = f1_score(y_true, y_pred, average='macro')
# plt.text(2, -1.5, f'Accuracy: {acc:.2f}\nPrecision: {prec:.2f}\nRecall: {rec:.2f}\nF1-score: {f1:.2f}', ha='center')

# Add colorbar
cbar = ax.figure.colorbar(im, ax=ax)
cbar.ax.set_ylabel('Normalized Counts', rotation=-90, va="bottom")

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Calculate performance metrics
acc = accuracy_score(y_true, y_pred)
prec = precision_score(y_true, y_pred, average='macro')
rec = recall_score(y_true, y_pred, average='macro')
f1 = f1_score(y_true, y_pred, average='macro')

# Plot performance metrics
metrics = ['Accuracy', 'Precision', 'Recall', 'F1-score']
values = [acc, prec, rec, f1]
colors = ['blue', 'red', 'green', 'orange']

fig, ax = plt.subplots()
ax.bar(metrics, values, color=colors)
ax.set_ylim([0, 1])
ax.set_title('Average Performance Metrics')
ax.set_ylabel('Value')
ax.grid(axis='y')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Calculate performance metrics
acc = accuracy_score(y_true, y_pred)
prec = precision_score(y_true, y_pred, average='macro')
rec = recall_score(y_true, y_pred, average='macro')
f1 = f1_score(y_true, y_pred, average='macro')

# Plot performance metrics
metrics = ['Accuracy', 'Precision', 'Recall', 'F1-score']
values = [acc, prec, rec, f1]
colors = ['blue', 'red', 'green', 'orange']

fig, ax = plt.subplots()
ax.bar(metrics, values, color=colors)
ax.set_ylim([0, 1])
ax.set_title('Average Performance Metrics')
ax.set_ylabel('Value')
ax.grid(axis='y')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Calculate performance metrics
acc = accuracy_score(y_true, y_pred)
prec = precision_score(y_true, y_pred, average='macro')
rec = recall_score(y_true, y_pred, average='macro')
f1 = f1_score(y_true, y_pred, average='macro')

# Plot performance metrics
metrics = ['Accuracy', 'Precision', 'Recall', 'F1-score']
values = [acc, prec, rec, f1]
colors = ['blue', 'red', 'green', 'orange']

fig, ax = plt.subplots(figsize=(6, 4))
ax.bar(metrics, values, color=colors, label='Performance Metrics')
ax.set_ylim([0, 1])
ax.set_title('Average Performance Metrics', fontsize=13)
ax.set_ylabel('Value', fontsize=12)
ax.tick_params(axis='both', labelsize=12)
ax.grid(axis='y')
# ax.legend(fontsize=12)

plt.gca().set_facecolor('white')
plt.tight_layout()
plt.savefig('performance_metrics.png', dpi=300)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

# Dummy predicted and true labels
y_pred = ['left', 'right', 'up', 'down', 'left', 'up', 'up', 'down', 'left', 'left', 'up', 'right', 'down', 'down', 'left', 'right']
y_true = ['left', 'right', 'up', 'down', 'right', 'up', 'down', 'down', 'right', 'left', 'up', 'right', 'down', 'down', 'left', 'right']

# Create confusion matrix
cm = confusion_matrix(y_true, y_pred, labels=['left', 'right', 'up', 'down'])
cm_norm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis] # Normalize

# Plot confusion matrix
fig, ax = plt.subplots(figsize=(8, 6))
im = ax.imshow(cm_norm, interpolation='nearest', cmap=plt.cm.Blues)
ax.set(xticks=np.arange(cm_norm.shape[1]), yticks=np.arange(cm_norm.shape[0]),
       xticklabels=['left', 'right', 'up', 'down'], yticklabels=['left', 'right', 'up', 'down'],
       title='Normalized Confusion Matrix', ylabel='True label', xlabel='Predicted label')
plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")

# Add values to the plot
thresh = cm_norm.max() / 2.
for i in range(cm_norm.shape[0]):
    for j in range(cm_norm.shape[1]):
        ax.text(j, i, format(cm_norm[i, j], '.2f'), ha="center", va="center",
                color="white" if cm_norm[i, j] > thresh else "black")

# Display average performance metrics
acc = accuracy_score(y_true, y_pred)
prec = precision_score(y_true, y_pred, average='macro')
rec = recall_score(y_true, y_pred, average='macro')
f1 = f1_score(y_true, y_pred, average='macro')
print(f'Accuracy: {acc:.2f}, Precision: {prec:.2f}, Recall: {rec:.2f}, F1-score: {f1:.2f}')

# Add colorbar
cbar = ax.figure.colorbar(im, ax=ax)
cbar.ax.set_ylabel('Normalized Counts', rotation=-90, va="bottom")

plt.show()
# Out:
# Accuracy: 0.81, Precision: 0.84, Recall: 0.85, F1-score: 0.81

# %%
import numpy as np
import matplotlib.pyplot as plt

# Calculate performance metrics
acc = accuracy_score(y_true, y_pred)
prec = precision_score(y_true, y_pred, average='macro')
rec = recall_score(y_true, y_pred, average='macro')
f1 = f1_score(y_true, y_pred, average='macro')

# Define lighter, pastel shades of the original colors
colors = ['#BFD7EA', '#FFC4C4', '#C9E2C7', '#FFE5B4']

# Add transparency to the colors
alphas = [0.8, 0.8, 0.8, 0.8]
colors = [color + (alpha,) for color, alpha in zip(colors, alphas)]

# Plot performance metrics
metrics = ['Accuracy', 'Precision', 'Recall', 'F1-score']
values = [acc, prec, rec, f1]

# fig, ax = plt.subplots(figsize=(6, 4))
ax.bar(metrics, values, color=colors, label='Performance Metrics')
ax.set_ylim([0, 1])
ax.set_title('Average Performance Metrics', fontsize=16)
ax.set_ylabel('Value', fontsize=12)
ax.tick_params(axis='both', labelsize=12)
ax.grid(axis='y')

ax.legend(fontsize=12)
plt.gca().set_facecolor('white')
plt.tight_layout()
plt.savefig('performance_metrics.png', dpi=300)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/2v/rqzdmr5s1q1d9vqx9sm4tn600000gn/T/ipykernel_46675/1190850888.py in <module>
#      13 # Add transparency to the colors
#      14 alphas = [0.8, 0.8, 0.8, 0.8]
# ---> 15 colors = [color + (alpha,) for color, alpha in zip(colors, alphas)]
#      16
#      17 # Plot performance metrics
#
# /var/folders/2v/rqzdmr5s1q1d9vqx9sm4tn600000gn/T/ipykernel_46675/1190850888.py in <listcomp>(.0)
#      13 # Add transparency to the colors
#      14 alphas = [0.8, 0.8, 0.8, 0.8]
# ---> 15 colors = [color + (alpha,) for color, alpha in zip(colors, alphas)]
#      16
#      17 # Plot performance metrics
#
# TypeError: can only concatenate str (not "tuple") to str

# %%
import numpy as np
import matplotlib.pyplot as plt

# Calculate performance metrics
acc = accuracy_score(y_true, y_pred)
prec = precision_score(y_true, y_pred, average='macro')
rec = recall_score(y_true, y_pred, average='macro')
f1 = f1_score(y_true, y_pred, average='macro')

# Define lighter, pastel shades of the original colors
colors = ['#BFD7EA', '#FFC4C4', '#C9E2C7', '#FFE5B4']

# Convert colors to RGBA tuples
colors = [plt.colors.hex2color(color) for color in colors]

# Add transparency to the colors
alphas = [0.8, 0.8, 0.8, 0.8]
colors = [color + (alpha,) for color, alpha in zip(colors, alphas)]

# Plot performance metrics
metrics = ['Accuracy', 'Precision', 'Recall', 'F1-score']
values = [acc, prec, rec, f1]

fig, ax = plt.subplots(figsize=(6, 4))
ax.bar(metrics, values, color=colors, label='Performance Metrics')
ax.set_ylim([0, 1])
ax.set_title('Average Performance Metrics', fontsize=13)
ax.set_ylabel('Value', fontsize=12)
ax.tick_params(axis='both', labelsize=12)
ax.grid(axis='y')
ax.legend(fontsize=12)

plt.gca().set_facecolor('white')
plt.tight_layout()
plt.savefig('performance_metrics.png', dpi=300)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/2v/rqzdmr5s1q1d9vqx9sm4tn600000gn/T/ipykernel_46675/131967856.py in <module>
#      12
#      13 # Convert colors to RGBA tuples
# ---> 14 colors = [plt.colors.hex2color(color) for color in colors]
#      15
#      16 # Add transparency to the colors
#
# /var/folders/2v/rqzdmr5s1q1d9vqx9sm4tn600000gn/T/ipykernel_46675/131967856.py in <listcomp>(.0)
#      12
#      13 # Convert colors to RGBA tuples
# ---> 14 colors = [plt.colors.hex2color(color) for color in colors]
#      15
#      16 # Add transparency to the colors
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'colors'

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

# Calculate performance metrics
acc = accuracy_score(y_true, y_pred)
prec = precision_score(y_true, y_pred, average='macro')
rec = recall_score(y_true, y_pred, average='macro')
f1 = f1_score(y_true, y_pred, average='macro')

# Define lighter, pastel shades of the original colors
colors = ['#BFD7EA', '#FFC4C4', '#C9E2C7', '#FFE5B4']

# Convert colors to RGBA tuples
colors_rgba = [mcolors.to_rgba(color) for color in colors]

# Add transparency to the colors
alphas = [0.8, 0.8, 0.8, 0.8]
colors_with_alpha = [color_rgba + (alpha,) for color_rgba, alpha in zip(colors_rgba, alphas)]

# Plot performance metrics
metrics = ['Accuracy', 'Precision', 'Recall', 'F1-score']
values = [acc, prec, rec, f1]

fig, ax = plt.subplots(figsize=(6, 4))
ax.bar(metrics, values, color=colors_with_alpha, label='Performance Metrics')
ax.set_ylim([0, 1])
ax.set_title('Average Performance Metrics', fontsize=16)
ax.set_ylabel('Value', fontsize=12)
ax.tick_params(axis='both', labelsize=12)
ax.grid(axis='y')

ax.legend(fontsize=12)
plt.gca().set_facecolor('white')
plt.tight_layout()
plt.savefig('performance_metrics.png', dpi=300)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/2v/rqzdmr5s1q1d9vqx9sm4tn600000gn/T/ipykernel_46675/4159832233.py in <module>
#      24
#      25 fig, ax = plt.subplots(figsize=(6, 4))
# ---> 26 ax.bar(metrics, values, color=colors_with_alpha, label='Performance Metrics')
#      27 ax.set_ylim([0, 1])
#      28 ax.set_title('Average Performance Metrics', fontsize=16)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
#    1411         if data is None:
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1413
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
# ...
